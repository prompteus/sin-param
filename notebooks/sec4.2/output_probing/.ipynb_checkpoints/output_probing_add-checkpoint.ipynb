# %%
device = "cuda:2"

# %% [markdown]
# ### Preliminaries

# %%
import itertools
import random
import collections


import transformers
import torch
import tqdm.auto
from torch import Tensor

# %%
def sinusoidal_encode(
    x: Tensor,
    embedding_dim: int,
    min_value: int,
    max_value: int,
    use_l2_norm: bool = False,
    norm_const: float | None = None,
) -> Tensor:
    """
    Encodes a tensor of numbers into a sinusoidal representation, inspired by how absolute positional
    encoding works in transformers.

    The encoding is an evaluation of a sine and cosine function at different frequencies, where the
    frequency is determined by the embedding dimension and the allowed range of the input values.

    >>> sinusoidal_encode(
    ...     torch.tensor([-5, 2, 1, 0]),
    ...     embedding_dim=6,
    ...     min_value=-5,
    ...     max_value=5,
    ... )
    tensor([[ 0.0000,  1.0000,  0.0000,  1.0000,  0.0000,  1.0000],
            [ 0.6570,  0.7539, -0.1073, -0.9942,  0.9980,  0.0627],
            [-0.2794,  0.9602,  0.3491, -0.9371,  0.9616,  0.2746],
            [-0.9589,  0.2837,  0.7317, -0.6816,  0.8806,  0.4738]])
    """

    if embedding_dim % 2 != 0 and not use_l2_norm:
        raise ValueError("Embedding dimension must be even")

    if use_l2_norm:
        if embedding_dim % 2 == 0:
            reserved_dim = 2
        else:
            reserved_dim = 1
        embedding_dim -= reserved_dim
    else:
        reserved_dim = 0  # will not be used

    domain = max_value - min_value
    y_shape = x.shape + (embedding_dim,)
    y = torch.zeros(y_shape, device=x.device)
    even_indices = torch.arange(0, embedding_dim, 2)
    log_term = torch.log(torch.tensor(domain)) / embedding_dim
    div_term = torch.exp(even_indices * -log_term)
    x = x - min_value
    values = x.unsqueeze(-1).float() * div_term
    y[..., 0::2] = torch.sin(values)
    y[..., 1::2] = torch.cos(values)

    if use_l2_norm:
        y = torch.cat([y, torch.ones_like(y[..., :reserved_dim])], dim=-1)
        y /= y.norm(dim=-1, keepdim=True, p=2)

    if norm_const is not None:
        y *= norm_const

    return y


def binary_encode(
    x: Tensor,
    embedding_dim: int,
    min_value: int | float,
    max_value: int | float,
    use_l2_norm: bool = False,
    norm_const: float | None = None,
) -> Tensor:
    y = torch.zeros(x.shape + (embedding_dim,), device=x.device)
    reserve_dim = 0 if not use_l2_norm else 1
    x = x - min_value
    maximum = x.max()
    for i in range(embedding_dim - reserve_dim):
        coeff = 2**i
        if maximum < coeff:
            break
        y[..., -i - 1] = torch.floor(x / coeff) % 2
        x = x - coeff * y[..., -i - 1]
    if use_l2_norm:
        y = torch.cat([y, torch.ones_like(y[..., :reserve_dim])], dim=-1)
        y /= y.norm(dim=-1, keepdim=True, p=2)
    if norm_const is not None:
        y *= norm_const
    return y

# %% [markdown]
# ### Prepare model and data

# %%
model_ckpt = "meta-llama/Llama-3.2-3B"
model = transformers.AutoModel.from_pretrained(model_ckpt).eval()
tokenizer = transformers.AutoTokenizer.from_pretrained(model_ckpt)
model = model.half().to(device).eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
all_values = torch.arange(1, 1000)
mask = torch.rand(len(all_values), generator=torch.Generator().manual_seed(0))
train_mask = mask < 0.9
valid_mask = ~train_mask & (mask < 0.95)
test_mask = ~train_mask & ~valid_mask

train_values = all_values[train_mask]
valid_values = all_values[valid_mask]
test_values = all_values[test_mask]

# %%
all_inputs = [(x1, x2) for x1, x2 in itertools.product(all_values.tolist(), repeat=2) if x1 + x2 < 1000]
train_values_set = set(train_values.tolist())
valid_values_set = set(valid_values.tolist())
test_values_set = set(test_values.tolist())

all_inputs = [(x1, x2) for x1, x2 in itertools.product(all_values.tolist(), repeat=2) if x1 + x2 < 1000]
train_values_set = set(train_values.tolist())
valid_values_set = set(valid_values.tolist())
test_values_set = set(test_values.tolist())

train_inputs = [(x1, x2) for x1, x2 in all_inputs if x1 + x2 in train_values_set]
valid_inputs = [(x1, x2) for x1, x2 in all_inputs if x1 + x2 in valid_values_set]
test_inputs = [(x1, x2) for x1, x2 in all_inputs if x1 + x2 in test_values_set]

# sanity check
assert set(train_inputs) & set(valid_inputs) == set()
assert set(train_inputs) & set(test_inputs) == set()
assert set(valid_inputs) & set(test_inputs) == set()

assert set(train_inputs) & set(valid_inputs) == set()
assert set(train_inputs) & set(test_inputs) == set()
assert set(valid_inputs) & set(test_inputs) == set()

random.seed(0)
random.shuffle(train_inputs)
random.shuffle(valid_inputs)
random.shuffle(test_inputs)

random.shuffle(train_inputs)
random.shuffle(valid_inputs)
random.shuffle(test_inputs)

valid_size = 4096
train_size = 50_000
train_inputs = train_inputs[:train_size]
train_inputs = train_inputs[:train_size]
valid_inputs = valid_inputs[:valid_size]

# %%
valid_values_set
# Out:
# {22,
#  32,
#  38,
#  74,
#  75,
#  76,
#  82,
#  171,
#  208,
#  219,
#  232,
#  234,
#  253,
#  269,
#  277,
#  286,
#  339,
#  343,
#  346,
#  367,
#  377,
#  378,
#  381,
#  384,
#  413,
#  433,
#  446,
#  451,
#  456,
#  495,
#  499,
#  505,
#  546,
#  571,
#  576,
#  613,
#  616,
#  619,
#  627,
#  648,
#  653,
#  670,
#  681,
#  708,
#  720,
#  721,
#  736,
#  746,
#  754,
#  768,
#  806,
#  818,
#  892,
#  901,
#  915,
#  935,
#  978}

# %%
[x for x in train_inputs if x[0] + x[1] not in train_values_set]
# Out:
# []

# %%
# division template

# num_templates = 6
#
# def make_str_input(operands: tuple[int, int] | list[int], template_idx: int = 1) -> str:
#     x1, x2 = operands
#     options = [
#         f"{x1} / {x2} is ",
#         f"{x1} divided by {x2} is ",
#         f"{x1} divided by {x2} equals to ",
#         f"{x1} / {x2} = ",
#         f"A division of {x1} by {x2} equals to ",
#         f"A result of dividing {x1} by {x2} is ",
#     ]
#     assert num_templates == len(options)
#     # return f"{x1} times {x2} is "  # 0.78
#     # return f"{x1} multiplied by {x2} is "  # 90.38
#     return options[template_idx]
#
# make_str_input((3, 500)), make_str_input((3, 0))

# %%
def make_str_input_add(operands: tuple[int, int] | list[int]) -> str:
    x1, x2 = operands
    return f"{x1} plus {x2} is equal to "

make_str_input_add((3, 500)), make_str_input_add((3, 0))
# Out:
# ('3 plus 500 is equal to ', '3 plus 0 is equal to ')

# %%
tokenizer('3 plus 500 is equal to ').input_ids
# Out:
# [128000, 18, 5636, 220, 2636, 374, 6273, 311, 220]

# %%
def get_hidden_states_and_preds(model, str_inputs: list[str], batch_size: int) -> tuple[dict[int, Tensor], list[str]]:
    model.eval()
    hidden_states = collections.defaultdict(list)
    model_preds = []
    with torch.no_grad():
        num_batches = (len(str_inputs) + batch_size - 1) // batch_size
        for batch_str in tqdm.auto.tqdm(itertools.batched(str_inputs, n=batch_size), total=num_batches, desc="Inferring model hidden states"):
            batch_inputs = tokenizer(batch_str, return_tensors="pt")
            model_outputs = model(**batch_inputs.to(model.device), output_hidden_states=True)
            hidden_reprs = model_outputs.hidden_states
            logits = model_outputs.last_hidden_state @ model.embed_tokens.weight.T
            next_token_ids = logits[:, -1, :].argmax(dim=-1)
            model_preds.extend(tokenizer.batch_decode(next_token_ids))

            for layer_idx, hidden_state in enumerate(hidden_reprs):
                hidden_states[layer_idx].extend(hidden_state[:, -1, :].detach().cpu())
    return {k: torch.stack(v) for k, v in hidden_states.items()}, model_preds

# %%
batch_size = 1024
# also tried with sin probes:
# train_hidden_states, train_preds = get_hidden_states_and_preds(
#         model,
#         [make_str_input(val, 0) for val in train_inputs] + [make_str_input(val, 1) for val in train_inputs] + [make_str_input(val, 2) for val in train_inputs],
#         batch_size
# )

# multiplication only:
# states_preds = (
#     [get_hidden_states_and_preds(model, [make_str_input(val, i) for val in train_inputs], batch_size) for i in range(num_templates)]
# )
# train_labels_ref = torch.tensor([x1 * x2 for _ in range(num_templates) for x1, x2 in train_inputs])

# multiplication+addition:
states_preds = (
    [get_hidden_states_and_preds(model, [make_str_input_add(val) for val in train_inputs], batch_size)]
)
train_labels_ref = torch.tensor([x1 + x2 for x1, x2 in train_inputs], device=device, dtype=torch.long)

hidden_states_all = [x[0] for x in states_preds]
preds_all = [x[1] for x in states_preds]

train_hidden_states = hidden_states_all[0]

train_preds = list(itertools.chain(*preds_all))
# Out:
# Inferring model hidden states:   0%|          | 0/49 [00:00<?, ?it/s]

# %%
# val and test contain only multuplication in either case
valid_hidden_states, valid_preds = get_hidden_states_and_preds(
        model,
        [make_str_input_add(val) for val in valid_inputs],
        batch_size
)
valid_labels_ref = torch.tensor([x1 + x2 for x1, x2 in valid_inputs], device=device, dtype=torch.long)
test_hidden_states, test_preds = get_hidden_states_and_preds(
        model,
        [make_str_input_add(val) for val in test_inputs],
        batch_size
)
test_labels_ref = torch.tensor([x1 + x2 for x1, x2 in test_inputs], device=device, dtype=torch.long)
# Out:
# Inferring model hidden states:   0%|          | 0/4 [00:00<?, ?it/s]
# Inferring model hidden states:   0%|          | 0/31 [00:00<?, ?it/s]

# %%
train_inputs_t = torch.tensor(train_inputs)

train_inputs_t[:, 0] + train_inputs_t[:, 1]
# Out:
# tensor([383, 405, 959,  ..., 995, 714, 873])

# %%
def sanitize_pred(pred: str) -> int:
    try:
        return int(pred)
    except ValueError:
        return -1

# %%
test_inputs_t = torch.tensor(test_inputs)

train_preds_t = torch.tensor([sanitize_pred(pred) for pred in train_preds])
valid_preds_t = torch.tensor([sanitize_pred(pred) for pred in valid_preds])
test_preds_t = torch.tensor([sanitize_pred(pred) for pred in test_preds])

# ratio of properly extracted train predictions
sum(train_preds_t != -1) / len(train_preds_t)
# Out:
# tensor(1.)

# %%
test_preds_t.device, test_labels_ref.device
# Out:
# (device(type='cpu'), device(type='cuda', index=2))

# %%
# absolute model accuracy on test set
sum(test_preds_t.to(device) == test_labels_ref) / len(test_inputs)
# Out:
# tensor(0.9465, device='cuda:2')

# %%
# absolute model accuracy on test set
sum(test_preds_t.to(device) == test_labels_ref) / len(test_inputs)
# Out:
# tensor(0.9465, device='cuda:2')

# %% [markdown]
# ### Probing

# %%
class ClassifierProbe(torch.nn.Module):
    basis: torch.Tensor

    def __init__(self, emb_dim: int, hidden_dim: int, heldout_mask: torch.Tensor):
        super().__init__()
        self.emb_to_latent = torch.nn.Linear(emb_dim, hidden_dim, bias=True)
        self.basis_to_latent = torch.nn.Linear(self.basis.shape[-1], hidden_dim, bias=True)
        self.basis = self.basis.to(device)
        self.heldout_mask: torch.nn.Buffer
        # self.register_buffer("basis", self.basis)
        self.register_buffer("heldout_mask", heldout_mask)
    def forward(self, x: Tensor, holdout_eval_tokens: bool) -> Tensor:
        latent_x = self.emb_to_latent(x)
        # during training, model learns to choose among only training tokens
        # but during eval, model must choose among all tokens
        # this means that the model is never exposed to the eval tokens during training
        latent_choices = self.basis_to_latent(self.basis)
        logits = latent_x @ latent_choices.T
        if holdout_eval_tokens:
            logits[:, self.heldout_mask] = float("-inf")
        return logits

# %%
class SinProbeOld(ClassifierProbe):

    def __init__(self, *args, **kwargs):
        self.basis = sinusoidal_encode(torch.arange(1000), min_value=0, max_value=1000,
                                       embedding_dim=train_hidden_states[0].shape[-1])
        super().__init__(*args, **kwargs)

class BinProbe(ClassifierProbe):

    def __init__(self, *args, **kwargs):
        self.basis = binary_encode(torch.arange(1000), min_value=0, max_value=1000, embedding_dim=10).to(device)
        super().__init__(*args, **kwargs)

# %%
class SinProbeNew(torch.nn.Module):
    def __init__(self, emb_dim: int, hidden_dim: int, choices: torch.Tensor, heldout_mask: torch.Tensor):
        super().__init__()
        self.emb_to_latent = torch.nn.Linear(emb_dim, hidden_dim, bias=True)
        self.freqs = torch.nn.Parameter(torch.linspace(1/(choices.max() - choices.min()), 0.5, steps=hidden_dim))
        self.phases = torch.nn.Parameter(torch.zeros(hidden_dim))
        self.amplitudes = torch.nn.Parameter(torch.zeros(hidden_dim))
        # self.accels = torch.nn.Parameter(torch.zeros(hidden_dim))
        self.hidden_dim = hidden_dim
        self.heldout_mask: torch.nn.Buffer
        self.choices: torch.nn.Buffer
        self.register_buffer("heldout_mask", heldout_mask)
        self.register_buffer("choices", choices)

    def get_waves(self) -> Tensor:
        # USE THIS FORMULA
        waves = torch.sin(
            self.phases.unsqueeze(1)
            + (2 * torch.pi * self.freqs.unsqueeze(1) * self.choices.unsqueeze(0))
            # + (2 * torch.pi * self.accels.unsqueeze(1) * torch.log(self.choices.unsqueeze(0) + 1e-4))
        )
        # sort by frequency
        waves = waves[torch.argsort(self.freqs.abs()), :]
        assert waves.shape == (self.hidden_dim, len(self.choices))
        return waves * self.amplitudes.unsqueeze(1)

    def forward(self, x: Tensor, holdout_eval_tokens: bool) -> Tensor:
        latent_x = self.emb_to_latent(x)
        waves = self.get_waves()
        logits = latent_x @ waves

        # during training, model learns to choose among only training tokens
        # but during eval, model must choose among all tokens
        # this means that the model is never exposed to the eval tokens during training
        if holdout_eval_tokens:
            logits[:, self.heldout_mask] = -torch.inf
        return logits

# %%
# model's own predictions as labels

# train_labels = train_preds_t.detach().clone()
# train_hidden_states = {k: v[train_labels != -1] for k, v in train_hidden_states.items()}
# train_labels = train_labels[train_labels != -1]
#
# valid_labels = valid_preds_t.detach().clone()
# valid_hidden_states = {k: v[valid_labels != -1] for k, v in valid_hidden_states.items()}
# valid_labels = valid_labels[valid_labels != -1].to(device)
#
# test_labels = test_preds_t.detach().clone()
# test_hidden_states = {k: v[test_labels != -1] for k, v in test_hidden_states.items()}
# test_labels = test_labels[test_labels != -1].to(device)

# %%
# true results as labels
train_labels = train_labels_ref
valid_labels = valid_labels_ref
test_labels = test_labels_ref

# %%
# how many of the model outputs are valid numbers (=usable as labels in training)
sum(train_preds_t != -1) / len(train_preds_t)
# Out:
# tensor(1.)

# %%
torch.set_num_threads(1)

test_extracted = {}

test_accuracies = {"sin_new": {}, "sin_old": {}, "bin": {}, "lin": {}, "log": {}}

# for layer_idx in reversed(range(len(train_hidden_states))):

# for development, iterate only on the last 3 layers -- where this should actually work:
for layer_idx in list(reversed(train_hidden_states.keys())):

    for probe_name, probe in {
            # "bin": BinProbe(
            #             emb_dim=train_hidden_states[0].shape[-1],
            #             hidden_dim=100,
            #             heldout_mask=test_mask,
            #         ).to(device),
            # "sin_old": SinProbeOld(
            #             emb_dim=train_hidden_states[0].shape[-1],
            #             hidden_dim=100,
            #             heldout_mask=test_mask,
            #         ).to(device),
            "sin_new": SinProbeNew(
                        emb_dim=train_hidden_states[0].shape[-1],
                        hidden_dim=2000,
                        choices=torch.arange(1000),
                        heldout_mask=test_mask,
                    ).to(device),
                }.items():  # NOTE: results of the last probe remain persisted in test_extracted!


        torch.manual_seed(0)

        optimizer = torch.optim.Adam(probe.parameters(), lr=1e-4, weight_decay=5e-3)
        # decaying LR is important for outputs probing and natural-lang contexts -- requiring inherently lower LR to fit
        scheduler = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=1.0, end_factor=0.1, total_iters=20000)

        rng = torch.Generator().manual_seed(0)
        best_val_acc = -1
        best_ckpt = None
        for i in range(30000+1):
            probe.train()
            optimizer.zero_grad()
            minibatch_idcs = torch.randint(len(train_labels), size=(8,), generator=rng)
            x = train_hidden_states[layer_idx][minibatch_idcs].float().to(device)
            y = train_labels[minibatch_idcs].to(device) - 1  # multiplication labels are in range <1, 999> to avoid division by zero
            logits = probe(x, holdout_eval_tokens=False)
            # add l1 regularization of all params to the loss
            assert logits.shape[1] >= max(y)
            assert min(y) >= 0

            loss = torch.nn.functional.cross_entropy(logits, y.long())
            # loss += 0.001 * (probe.emb_to_latent.weight.abs().sum() + probe.amplitudes.abs().sum())
            loss.backward()
            optimizer.step()
            scheduler.step()
            if i % 100 == 0:
                train_acc = (logits.argmax(dim=-1) == y).float().mean().item()
                probe.eval()
                with torch.no_grad():
                    valid_logits = probe(valid_hidden_states[layer_idx].float().to(device), holdout_eval_tokens=False)
                    valid_loss = torch.nn.functional.cross_entropy(valid_logits, valid_labels.long() - 1)
                    valid_accuracy = (valid_logits.argmax(dim=-1) + 1 == valid_labels).float().mean().item()
                    if valid_accuracy > best_val_acc:
                        best_val_acc = valid_accuracy
                        best_ckpt = probe.state_dict()
                print(f"{probe_name} {i=:>5} train loss: {loss.item():5.2f}  train acc: {train_acc:.2f}  val loss: {valid_loss.item():5.2f}  valid acc: {valid_accuracy:.2f}")
        probe.load_state_dict(best_ckpt)
        probe.eval()
        with torch.no_grad():
            test_logits = probe(test_hidden_states[layer_idx].float().to(device), holdout_eval_tokens=False)
            test_extracted[layer_idx] = test_logits.argmax(dim=-1) + 1
            test_accuracy = (test_extracted[layer_idx] == test_labels).float().mean().item()

        test_accuracies[probe_name][layer_idx] = test_accuracy
        print(f"-> {probe_name} layer idx: {layer_idx:<3}, best valid accuracy: {best_val_acc:.2f}, test accuracy: {test_accuracy:.2f}")

# save the results for visualizations & further analyses
import pandas as pd

df = pd.DataFrame({"probe_l%s" % k: v.cpu() for k, v in test_extracted.items()})
df["model_predictions"] = test_preds_t.cpu()
df["inputs"] = [make_str_input_add(op) for op in test_inputs]
df["labels"] = test_labels_ref.cpu()

# this output can be visualized using notebooks/viz/error_tracing.ipynb
df.to_csv("/home/USER/tmp/pycharm_project_437/notebooks/logs/model_vs_probes_preds_llama3b_add_040126_onlynewprobe.csv", index=False)
# Out:
# sin_new i=    0 train loss:  6.91  train acc: 0.00  val loss:  6.91  valid acc: 0.00
# sin_new i=  100 train loss:  6.83  train acc: 0.00  val loss:  6.66  valid acc: 0.00
# sin_new i=  200 train loss:  5.22  train acc: 0.25  val loss:  5.56  valid acc: 0.09
# sin_new i=  300 train loss:  2.48  train acc: 1.00  val loss:  3.78  valid acc: 0.45
# sin_new i=  400 train loss:  1.10  train acc: 1.00  val loss:  2.33  valid acc: 0.69
# sin_new i=  500 train loss:  1.68  train acc: 0.75  val loss:  1.55  valid acc: 0.76
# sin_new i=  600 train loss:  0.71  train acc: 1.00  val loss:  1.23  valid acc: 0.86
# sin_new i=  700 train loss:  0.28  train acc: 1.00  val loss:  0.86  valid acc: 0.90
# sin_new i=  800 train loss:  1.37  train acc: 0.88  val loss:  0.75  valid acc: 0.90
# sin_new i=  900 train loss:  0.39  train acc: 1.00  val loss:  0.65  valid acc: 0.91
# sin_new i= 1000 train loss:  0.38  train acc: 1.00  val loss:  0.65  valid acc: 0.91
# sin_new i= 1100 train loss:  0.60  train acc: 0.88  val loss:  0.51  valid acc: 0.93
# sin_new i= 1200 train loss:  0.28  train acc: 1.00  val loss:  0.46  valid acc: 0.93
# sin_new i= 1300 train loss:  0.19  train acc: 1.00  val loss:  0.45  valid acc: 0.93
# sin_new i= 1400 train loss:  0.12  train acc: 1.00  val loss:  0.46  valid acc: 0.93
# sin_new i= 1500 train loss:  0.76  train acc: 0.88  val loss:  0.43  valid acc: 0.93
# sin_new i= 1600 train loss:  0.52  train acc: 0.88  val loss:  0.48  valid acc: 0.91
# sin_new i= 1700 train loss:  0.33  train acc: 0.88  val loss:  0.34  valid acc: 0.94
# sin_new i= 1800 train loss:  0.08  train acc: 1.00  val loss:  0.44  valid acc: 0.93
# sin_new i= 1900 train loss:  0.13  train acc: 1.00  val loss:  0.39  valid acc: 0.94
# sin_new i= 2000 train loss:  0.14  train acc: 1.00  val loss:  0.36  valid acc: 0.93
# sin_new i= 2100 train loss:  0.16  train acc: 1.00  val loss:  0.35  valid acc: 0.93
# sin_new i= 2200 train loss:  0.08  train acc: 1.00  val loss:  0.31  valid acc: 0.94
# sin_new i= 2300 train loss:  0.10  train acc: 1.00  val loss:  0.36  valid acc: 0.94
# sin_new i= 2400 train loss:  0.10  train acc: 1.00  val loss:  0.35  valid acc: 0.94
# sin_new i= 2500 train loss:  0.47  train acc: 0.88  val loss:  0.31  valid acc: 0.94
# sin_new i= 2600 train loss:  0.08  train acc: 1.00  val loss:  0.29  valid acc: 0.94
# sin_new i= 2700 train loss:  0.10  train acc: 1.00  val loss:  0.37  valid acc: 0.94
# sin_new i= 2800 train loss:  0.04  train acc: 1.00  val loss:  0.36  valid acc: 0.93
# sin_new i= 2900 train loss:  0.05  train acc: 1.00  val loss:  0.33  valid acc: 0.93
# sin_new i= 3000 train loss:  0.39  train acc: 0.88  val loss:  0.32  valid acc: 0.94
# sin_new i= 3100 train loss:  0.13  train acc: 1.00  val loss:  0.32  valid acc: 0.94
# sin_new i= 3200 train loss:  0.11  train acc: 1.00  val loss:  0.36  valid acc: 0.93
# sin_new i= 3300 train loss:  0.51  train acc: 0.88  val loss:  0.36  valid acc: 0.92
# sin_new i= 3400 train loss:  0.17  train acc: 1.00  val loss:  0.37  valid acc: 0.94
# sin_new i= 3500 train loss:  0.07  train acc: 1.00  val loss:  0.25  valid acc: 0.95
# sin_new i= 3600 train loss:  0.05  train acc: 1.00  val loss:  0.30  valid acc: 0.94
# sin_new i= 3700 train loss:  0.60  train acc: 0.88  val loss:  0.29  valid acc: 0.94
# sin_new i= 3800 train loss:  0.15  train acc: 1.00  val loss:  0.28  valid acc: 0.94
# sin_new i= 3900 train loss:  0.14  train acc: 1.00  val loss:  0.31  valid acc: 0.93
# sin_new i= 4000 train loss:  0.03  train acc: 1.00  val loss:  0.30  valid acc: 0.95
# sin_new i= 4100 train loss:  0.18  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 4200 train loss:  0.17  train acc: 1.00  val loss:  0.33  valid acc: 0.94
# sin_new i= 4300 train loss:  0.11  train acc: 1.00  val loss:  0.31  valid acc: 0.94
# sin_new i= 4400 train loss:  0.01  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 4500 train loss:  0.07  train acc: 1.00  val loss:  0.38  valid acc: 0.92
# sin_new i= 4600 train loss:  0.35  train acc: 0.88  val loss:  0.27  valid acc: 0.94
# sin_new i= 4700 train loss:  0.80  train acc: 0.88  val loss:  0.31  valid acc: 0.93
# sin_new i= 4800 train loss:  0.18  train acc: 1.00  val loss:  0.25  valid acc: 0.95
# sin_new i= 4900 train loss:  0.11  train acc: 1.00  val loss:  0.28  valid acc: 0.94
# sin_new i= 5000 train loss:  0.03  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 5100 train loss:  0.26  train acc: 0.88  val loss:  0.20  valid acc: 0.95
# sin_new i= 5200 train loss:  0.01  train acc: 1.00  val loss:  0.25  valid acc: 0.94
# sin_new i= 5300 train loss:  0.05  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 5400 train loss:  0.07  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 5500 train loss:  0.28  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 5600 train loss:  0.03  train acc: 1.00  val loss:  0.25  valid acc: 0.95
# sin_new i= 5700 train loss:  0.38  train acc: 0.88  val loss:  0.31  valid acc: 0.94
# sin_new i= 5800 train loss:  0.02  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 5900 train loss:  0.19  train acc: 0.88  val loss:  0.22  valid acc: 0.95
# sin_new i= 6000 train loss:  0.02  train acc: 1.00  val loss:  0.28  valid acc: 0.94
# sin_new i= 6100 train loss:  0.18  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 6200 train loss:  0.02  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6300 train loss:  0.38  train acc: 0.88  val loss:  0.22  valid acc: 0.95
# sin_new i= 6400 train loss:  0.01  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6500 train loss:  0.08  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6600 train loss:  0.04  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6700 train loss:  0.10  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 6800 train loss:  0.49  train acc: 0.75  val loss:  0.30  valid acc: 0.94
# sin_new i= 6900 train loss:  0.24  train acc: 0.88  val loss:  0.22  valid acc: 0.95
# sin_new i= 7000 train loss:  0.54  train acc: 0.88  val loss:  0.24  valid acc: 0.95
# sin_new i= 7100 train loss:  0.01  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 7200 train loss:  0.24  train acc: 1.00  val loss:  0.21  valid acc: 0.96
# sin_new i= 7300 train loss:  0.05  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i= 7400 train loss:  0.30  train acc: 0.88  val loss:  0.23  valid acc: 0.95
# sin_new i= 7500 train loss:  1.08  train acc: 0.75  val loss:  0.22  valid acc: 0.95
# sin_new i= 7600 train loss:  0.07  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 7700 train loss:  0.10  train acc: 1.00  val loss:  0.39  valid acc: 0.90
# sin_new i= 7800 train loss:  0.03  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 7900 train loss:  0.03  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 8000 train loss:  1.27  train acc: 0.88  val loss:  0.21  valid acc: 0.95
# sin_new i= 8100 train loss:  0.07  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 8200 train loss:  0.17  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 8300 train loss:  0.01  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i= 8400 train loss:  0.71  train acc: 0.88  val loss:  0.21  valid acc: 0.95
# sin_new i= 8500 train loss:  0.14  train acc: 0.88  val loss:  0.34  valid acc: 0.93
# sin_new i= 8600 train loss:  0.03  train acc: 1.00  val loss:  0.21  valid acc: 0.96
# sin_new i= 8700 train loss:  0.40  train acc: 0.88  val loss:  0.21  valid acc: 0.95
# sin_new i= 8800 train loss:  0.02  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 8900 train loss:  0.12  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 9000 train loss:  0.01  train acc: 1.00  val loss:  0.25  valid acc: 0.95
# sin_new i= 9100 train loss:  0.10  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 9200 train loss:  0.21  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 9300 train loss:  0.01  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 9400 train loss:  0.23  train acc: 1.00  val loss:  0.18  valid acc: 0.95
# sin_new i= 9500 train loss:  0.15  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i= 9600 train loss:  0.10  train acc: 1.00  val loss:  0.19  valid acc: 0.96
# sin_new i= 9700 train loss:  0.14  train acc: 0.88  val loss:  0.19  valid acc: 0.95
# sin_new i= 9800 train loss:  0.07  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 9900 train loss:  0.08  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i=10000 train loss:  0.04  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i=10100 train loss:  0.15  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i=10200 train loss:  0.37  train acc: 0.88  val loss:  0.21  valid acc: 0.95
# sin_new i=10300 train loss:  0.04  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=10400 train loss:  0.04  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=10500 train loss:  0.86  train acc: 0.75  val loss:  0.20  valid acc: 0.96
# sin_new i=10600 train loss:  0.03  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=10700 train loss:  0.01  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i=10800 train loss:  0.02  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i=10900 train loss:  0.28  train acc: 0.88  val loss:  0.19  valid acc: 0.96
# sin_new i=11000 train loss:  0.01  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=11100 train loss:  0.33  train acc: 0.88  val loss:  0.20  valid acc: 0.95
# sin_new i=11200 train loss:  0.69  train acc: 0.75  val loss:  0.19  valid acc: 0.95
# sin_new i=11300 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=11400 train loss:  0.03  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=11500 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=11600 train loss:  0.03  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=11700 train loss:  0.03  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=11800 train loss:  0.19  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=11900 train loss:  0.02  train acc: 1.00  val loss:  0.20  valid acc: 0.96
# sin_new i=12000 train loss:  0.09  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=12100 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.97
# sin_new i=12200 train loss:  0.02  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i=12300 train loss:  0.04  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=12400 train loss:  0.03  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=12500 train loss:  0.31  train acc: 0.75  val loss:  0.15  valid acc: 0.96
# sin_new i=12600 train loss:  0.03  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=12700 train loss:  0.60  train acc: 0.88  val loss:  0.16  valid acc: 0.96
# sin_new i=12800 train loss:  0.06  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=12900 train loss:  0.02  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=13000 train loss:  0.39  train acc: 0.88  val loss:  0.15  valid acc: 0.96
# sin_new i=13100 train loss:  0.05  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=13200 train loss:  0.02  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=13300 train loss:  0.55  train acc: 0.88  val loss:  0.15  valid acc: 0.96
# sin_new i=13400 train loss:  0.10  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i=13500 train loss:  0.09  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i=13600 train loss:  0.05  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=13700 train loss:  0.03  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=13800 train loss:  0.08  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=13900 train loss:  0.04  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=14000 train loss:  0.37  train acc: 0.88  val loss:  0.16  valid acc: 0.96
# sin_new i=14100 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=14200 train loss:  0.23  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i=14300 train loss:  0.14  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=14400 train loss:  0.02  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=14500 train loss:  0.37  train acc: 0.88  val loss:  0.15  valid acc: 0.96
# sin_new i=14600 train loss:  0.02  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=14700 train loss:  0.01  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=14800 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=14900 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=15000 train loss:  0.49  train acc: 0.88  val loss:  0.15  valid acc: 0.96
# sin_new i=15100 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=15200 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=15300 train loss:  0.04  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=15400 train loss:  0.02  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=15500 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=15600 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=15700 train loss:  0.07  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=15800 train loss:  0.00  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=15900 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=16000 train loss:  0.18  train acc: 0.88  val loss:  0.17  valid acc: 0.96
# sin_new i=16100 train loss:  0.10  train acc: 1.00  val loss:  0.18  valid acc: 0.95
# sin_new i=16200 train loss:  0.02  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=16300 train loss:  0.02  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=16400 train loss:  0.67  train acc: 0.88  val loss:  0.14  valid acc: 0.96
# sin_new i=16500 train loss:  0.09  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=16600 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=16700 train loss:  0.05  train acc: 1.00  val loss:  0.29  valid acc: 0.93
# sin_new i=16800 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=16900 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=17000 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=17100 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=17200 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=17300 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17400 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=17500 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17600 train loss:  0.26  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=17700 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17800 train loss:  0.81  train acc: 0.88  val loss:  0.14  valid acc: 0.97
# sin_new i=17900 train loss:  0.12  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=18000 train loss:  0.07  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18100 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18200 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18300 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18400 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18500 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18700 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18800 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=18900 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19000 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19100 train loss:  0.21  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=19200 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19300 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=19400 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19500 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19600 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19700 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19800 train loss:  0.05  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=19900 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=20000 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20100 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20200 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20300 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20400 train loss:  0.11  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=20500 train loss:  0.24  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=20600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20700 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=20800 train loss:  0.08  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20900 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21000 train loss:  0.37  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=21100 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21200 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21300 train loss:  0.07  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21400 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21500 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21700 train loss:  0.38  train acc: 0.75  val loss:  0.12  valid acc: 0.97
# sin_new i=21800 train loss:  0.12  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21900 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22100 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22200 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22300 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=22400 train loss:  0.06  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=22500 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=22600 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=22700 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22800 train loss:  0.09  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=22900 train loss:  0.03  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=23000 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23100 train loss:  0.35  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23200 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23300 train loss:  0.37  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23400 train loss:  0.18  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23500 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23600 train loss:  0.27  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23700 train loss:  0.41  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23800 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=23900 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24100 train loss:  0.23  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=24200 train loss:  0.07  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24300 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24400 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24500 train loss:  0.19  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24600 train loss:  0.52  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=24700 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24800 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24900 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25000 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=25100 train loss:  0.09  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25200 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25300 train loss:  0.00  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25400 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25500 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25600 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25700 train loss:  0.30  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=25800 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25900 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=26000 train loss:  0.14  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=26100 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=26200 train loss:  0.19  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=26300 train loss:  0.32  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=26400 train loss:  0.01  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=26500 train loss:  0.11  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=26600 train loss:  0.02  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=26700 train loss:  0.03  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=26800 train loss:  0.05  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=26900 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=27000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=27100 train loss:  0.10  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=27200 train loss:  0.36  train acc: 0.88  val loss:  0.13  valid acc: 0.97
# sin_new i=27300 train loss:  0.06  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=27400 train loss:  0.02  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=27500 train loss:  0.09  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=27600 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=27700 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=27800 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=27900 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28000 train loss:  0.08  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28100 train loss:  0.07  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28200 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28300 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28400 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=28500 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28600 train loss:  0.03  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=28700 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28800 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=28900 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=29000 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=29100 train loss:  0.05  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=29200 train loss:  0.02  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=29300 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=29400 train loss:  0.05  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=29500 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=29600 train loss:  0.07  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=29700 train loss:  0.31  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=29800 train loss:  0.07  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=29900 train loss:  0.00  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=30000 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# -> sin_new layer idx: 28 , best valid accuracy: 0.97, test accuracy: 0.97
# sin_new i=    0 train loss:  6.91  train acc: 0.00  val loss:  6.91  valid acc: 0.00
# sin_new i=  100 train loss:  6.61  train acc: 0.00  val loss:  6.62  valid acc: 0.00
# sin_new i=  200 train loss:  4.68  train acc: 0.50  val loss:  5.08  valid acc: 0.38
# sin_new i=  300 train loss:  1.65  train acc: 1.00  val loss:  3.13  valid acc: 0.57
# sin_new i=  400 train loss:  0.77  train acc: 0.88  val loss:  1.95  valid acc: 0.68
# sin_new i=  500 train loss:  1.01  train acc: 0.88  val loss:  1.29  valid acc: 0.82
# sin_new i=  600 train loss:  0.52  train acc: 1.00  val loss:  1.08  valid acc: 0.87
# sin_new i=  700 train loss:  0.22  train acc: 1.00  val loss:  0.78  valid acc: 0.91
# sin_new i=  800 train loss:  1.35  train acc: 0.88  val loss:  0.69  valid acc: 0.92
# sin_new i=  900 train loss:  0.34  train acc: 1.00  val loss:  0.60  valid acc: 0.91
# sin_new i= 1000 train loss:  0.47  train acc: 1.00  val loss:  0.61  valid acc: 0.92
# sin_new i= 1100 train loss:  0.52  train acc: 0.88  val loss:  0.48  valid acc: 0.93
# sin_new i= 1200 train loss:  0.20  train acc: 1.00  val loss:  0.43  valid acc: 0.93
# sin_new i= 1300 train loss:  0.25  train acc: 1.00  val loss:  0.47  valid acc: 0.93
# sin_new i= 1400 train loss:  0.06  train acc: 1.00  val loss:  0.39  valid acc: 0.93
# sin_new i= 1500 train loss:  0.80  train acc: 0.88  val loss:  0.38  valid acc: 0.94
# sin_new i= 1600 train loss:  0.33  train acc: 1.00  val loss:  0.38  valid acc: 0.94
# sin_new i= 1700 train loss:  0.35  train acc: 0.88  val loss:  0.36  valid acc: 0.93
# sin_new i= 1800 train loss:  0.04  train acc: 1.00  val loss:  0.36  valid acc: 0.93
# sin_new i= 1900 train loss:  0.28  train acc: 1.00  val loss:  0.43  valid acc: 0.92
# sin_new i= 2000 train loss:  0.08  train acc: 1.00  val loss:  0.33  valid acc: 0.94
# sin_new i= 2100 train loss:  0.14  train acc: 1.00  val loss:  0.35  valid acc: 0.93
# sin_new i= 2200 train loss:  0.09  train acc: 1.00  val loss:  0.35  valid acc: 0.94
# sin_new i= 2300 train loss:  0.08  train acc: 1.00  val loss:  0.36  valid acc: 0.94
# sin_new i= 2400 train loss:  0.07  train acc: 1.00  val loss:  0.32  valid acc: 0.94
# sin_new i= 2500 train loss:  0.36  train acc: 0.88  val loss:  0.36  valid acc: 0.94
# sin_new i= 2600 train loss:  0.05  train acc: 1.00  val loss:  0.29  valid acc: 0.94
# sin_new i= 2700 train loss:  0.09  train acc: 1.00  val loss:  0.33  valid acc: 0.95
# sin_new i= 2800 train loss:  0.07  train acc: 1.00  val loss:  0.30  valid acc: 0.94
# sin_new i= 2900 train loss:  0.03  train acc: 1.00  val loss:  0.32  valid acc: 0.94
# sin_new i= 3000 train loss:  0.37  train acc: 0.88  val loss:  0.28  valid acc: 0.95
# sin_new i= 3100 train loss:  0.06  train acc: 1.00  val loss:  0.34  valid acc: 0.94
# sin_new i= 3200 train loss:  0.10  train acc: 1.00  val loss:  0.30  valid acc: 0.94
# sin_new i= 3300 train loss:  0.21  train acc: 1.00  val loss:  0.33  valid acc: 0.94
# sin_new i= 3400 train loss:  0.17  train acc: 1.00  val loss:  0.32  valid acc: 0.95
# sin_new i= 3500 train loss:  0.06  train acc: 1.00  val loss:  0.25  valid acc: 0.94
# sin_new i= 3600 train loss:  0.02  train acc: 1.00  val loss:  0.28  valid acc: 0.94
# sin_new i= 3700 train loss:  0.47  train acc: 0.88  val loss:  0.28  valid acc: 0.95
# sin_new i= 3800 train loss:  0.40  train acc: 0.88  val loss:  0.26  valid acc: 0.95
# sin_new i= 3900 train loss:  0.07  train acc: 1.00  val loss:  0.29  valid acc: 0.94
# sin_new i= 4000 train loss:  0.02  train acc: 1.00  val loss:  0.26  valid acc: 0.95
# sin_new i= 4100 train loss:  0.08  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 4200 train loss:  0.24  train acc: 0.88  val loss:  0.40  valid acc: 0.93
# sin_new i= 4300 train loss:  0.16  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 4400 train loss:  0.03  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 4500 train loss:  0.13  train acc: 1.00  val loss:  0.32  valid acc: 0.92
# sin_new i= 4600 train loss:  0.40  train acc: 0.88  val loss:  0.23  valid acc: 0.95
# sin_new i= 4700 train loss:  0.65  train acc: 0.88  val loss:  0.30  valid acc: 0.94
# sin_new i= 4800 train loss:  0.15  train acc: 1.00  val loss:  0.30  valid acc: 0.94
# sin_new i= 4900 train loss:  0.07  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 5000 train loss:  0.06  train acc: 1.00  val loss:  0.28  valid acc: 0.94
# sin_new i= 5100 train loss:  0.30  train acc: 0.88  val loss:  0.26  valid acc: 0.95
# sin_new i= 5200 train loss:  0.01  train acc: 1.00  val loss:  0.27  valid acc: 0.95
# sin_new i= 5300 train loss:  0.07  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 5400 train loss:  0.07  train acc: 1.00  val loss:  0.25  valid acc: 0.95
# sin_new i= 5500 train loss:  0.24  train acc: 0.88  val loss:  0.23  valid acc: 0.95
# sin_new i= 5600 train loss:  0.03  train acc: 1.00  val loss:  0.23  valid acc: 0.96
# sin_new i= 5700 train loss:  0.09  train acc: 1.00  val loss:  0.30  valid acc: 0.94
# sin_new i= 5800 train loss:  0.03  train acc: 1.00  val loss:  0.41  valid acc: 0.91
# sin_new i= 5900 train loss:  0.28  train acc: 0.88  val loss:  0.23  valid acc: 0.95
# sin_new i= 6000 train loss:  0.02  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 6100 train loss:  0.10  train acc: 1.00  val loss:  0.24  valid acc: 0.95
# sin_new i= 6200 train loss:  0.04  train acc: 1.00  val loss:  0.22  valid acc: 0.95
# sin_new i= 6300 train loss:  0.61  train acc: 0.75  val loss:  0.27  valid acc: 0.95
# sin_new i= 6400 train loss:  0.04  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 6500 train loss:  0.07  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6600 train loss:  0.03  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 6700 train loss:  0.37  train acc: 0.75  val loss:  0.23  valid acc: 0.95
# sin_new i= 6800 train loss:  0.20  train acc: 0.88  val loss:  0.23  valid acc: 0.95
# sin_new i= 6900 train loss:  0.12  train acc: 1.00  val loss:  0.20  valid acc: 0.96
# sin_new i= 7000 train loss:  0.30  train acc: 1.00  val loss:  0.20  valid acc: 0.96
# sin_new i= 7100 train loss:  0.01  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i= 7200 train loss:  0.15  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 7300 train loss:  0.05  train acc: 1.00  val loss:  0.23  valid acc: 0.95
# sin_new i= 7400 train loss:  0.22  train acc: 0.88  val loss:  0.20  valid acc: 0.95
# sin_new i= 7500 train loss:  0.71  train acc: 0.75  val loss:  0.20  valid acc: 0.95
# sin_new i= 7600 train loss:  0.05  train acc: 1.00  val loss:  0.20  valid acc: 0.96
# sin_new i= 7700 train loss:  0.07  train acc: 1.00  val loss:  0.31  valid acc: 0.93
# sin_new i= 7800 train loss:  0.03  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i= 7900 train loss:  0.06  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i= 8000 train loss:  1.05  train acc: 0.88  val loss:  0.21  valid acc: 0.95
# sin_new i= 8100 train loss:  0.04  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i= 8200 train loss:  0.20  train acc: 0.88  val loss:  0.18  valid acc: 0.95
# sin_new i= 8300 train loss:  0.01  train acc: 1.00  val loss:  0.19  valid acc: 0.95
# sin_new i= 8400 train loss:  0.70  train acc: 0.88  val loss:  0.20  valid acc: 0.96
# sin_new i= 8500 train loss:  0.03  train acc: 1.00  val loss:  0.27  valid acc: 0.93
# sin_new i= 8600 train loss:  0.03  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i= 8700 train loss:  0.50  train acc: 0.88  val loss:  0.20  valid acc: 0.95
# sin_new i= 8800 train loss:  0.02  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 8900 train loss:  0.09  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i= 9000 train loss:  0.02  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 9100 train loss:  0.10  train acc: 1.00  val loss:  0.20  valid acc: 0.95
# sin_new i= 9200 train loss:  0.25  train acc: 0.88  val loss:  0.18  valid acc: 0.96
# sin_new i= 9300 train loss:  0.01  train acc: 1.00  val loss:  0.19  valid acc: 0.96
# sin_new i= 9400 train loss:  0.21  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i= 9500 train loss:  0.22  train acc: 0.88  val loss:  0.17  valid acc: 0.96
# sin_new i= 9600 train loss:  0.04  train acc: 1.00  val loss:  0.19  valid acc: 0.96
# sin_new i= 9700 train loss:  0.17  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i= 9800 train loss:  0.02  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i= 9900 train loss:  0.08  train acc: 1.00  val loss:  0.21  valid acc: 0.95
# sin_new i=10000 train loss:  0.09  train acc: 1.00  val loss:  0.20  valid acc: 0.96
# sin_new i=10100 train loss:  0.41  train acc: 0.88  val loss:  0.22  valid acc: 0.95
# sin_new i=10200 train loss:  0.24  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=10300 train loss:  0.05  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=10400 train loss:  0.02  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=10500 train loss:  0.87  train acc: 0.88  val loss:  0.20  valid acc: 0.96
# sin_new i=10600 train loss:  0.04  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=10700 train loss:  0.02  train acc: 1.00  val loss:  0.19  valid acc: 0.96
# sin_new i=10800 train loss:  0.05  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=10900 train loss:  0.14  train acc: 0.88  val loss:  0.17  valid acc: 0.96
# sin_new i=11000 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=11100 train loss:  0.14  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=11200 train loss:  0.56  train acc: 0.75  val loss:  0.16  valid acc: 0.96
# sin_new i=11300 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=11400 train loss:  0.03  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=11500 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=11600 train loss:  0.05  train acc: 1.00  val loss:  0.18  valid acc: 0.96
# sin_new i=11700 train loss:  0.01  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=11800 train loss:  0.16  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=11900 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=12000 train loss:  0.20  train acc: 0.88  val loss:  0.16  valid acc: 0.96
# sin_new i=12100 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=12200 train loss:  0.01  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=12300 train loss:  0.02  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=12400 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=12500 train loss:  0.31  train acc: 0.88  val loss:  0.14  valid acc: 0.96
# sin_new i=12600 train loss:  0.04  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=12700 train loss:  0.54  train acc: 0.88  val loss:  0.14  valid acc: 0.97
# sin_new i=12800 train loss:  0.05  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=12900 train loss:  0.02  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=13000 train loss:  0.37  train acc: 0.88  val loss:  0.17  valid acc: 0.96
# sin_new i=13100 train loss:  0.05  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=13200 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=13300 train loss:  0.41  train acc: 0.88  val loss:  0.13  valid acc: 0.96
# sin_new i=13400 train loss:  0.10  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=13500 train loss:  0.10  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=13600 train loss:  0.04  train acc: 1.00  val loss:  0.17  valid acc: 0.96
# sin_new i=13700 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=13800 train loss:  0.27  train acc: 0.88  val loss:  0.14  valid acc: 0.97
# sin_new i=13900 train loss:  0.03  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=14000 train loss:  0.49  train acc: 0.75  val loss:  0.16  valid acc: 0.96
# sin_new i=14100 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=14200 train loss:  0.10  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=14300 train loss:  0.23  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=14400 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=14500 train loss:  0.13  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=14600 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=14700 train loss:  0.01  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=14800 train loss:  0.00  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=14900 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=15000 train loss:  0.39  train acc: 0.88  val loss:  0.15  valid acc: 0.97
# sin_new i=15100 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.97
# sin_new i=15200 train loss:  0.03  train acc: 1.00  val loss:  0.18  valid acc: 0.95
# sin_new i=15300 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=15400 train loss:  0.03  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=15500 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=15600 train loss:  0.01  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=15700 train loss:  0.09  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=15800 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=15900 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=16000 train loss:  0.15  train acc: 1.00  val loss:  0.15  valid acc: 0.96
# sin_new i=16100 train loss:  0.13  train acc: 1.00  val loss:  0.16  valid acc: 0.96
# sin_new i=16200 train loss:  0.03  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=16300 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=16400 train loss:  0.83  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=16500 train loss:  0.10  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=16600 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=16700 train loss:  0.05  train acc: 1.00  val loss:  0.20  valid acc: 0.94
# sin_new i=16800 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=16900 train loss:  0.02  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=17000 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17100 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=17200 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=17300 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17400 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17500 train loss:  0.02  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=17600 train loss:  0.23  train acc: 1.00  val loss:  0.14  valid acc: 0.96
# sin_new i=17700 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=17800 train loss:  0.52  train acc: 0.88  val loss:  0.13  valid acc: 0.97
# sin_new i=17900 train loss:  0.13  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18000 train loss:  0.05  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18100 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18200 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18300 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18400 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18500 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18700 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=18800 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=18900 train loss:  0.00  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19100 train loss:  0.10  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19200 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19300 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19400 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.96
# sin_new i=19500 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19600 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19700 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=19800 train loss:  0.04  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=19900 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20000 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20100 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20200 train loss:  0.01  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=20300 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20400 train loss:  0.08  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20500 train loss:  0.24  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=20600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20700 train loss:  0.01  train acc: 1.00  val loss:  0.14  valid acc: 0.97
# sin_new i=20800 train loss:  0.06  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=20900 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21000 train loss:  0.29  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=21100 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21200 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21300 train loss:  0.08  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=21400 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21500 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21600 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21700 train loss:  0.31  train acc: 0.75  val loss:  0.12  valid acc: 0.97
# sin_new i=21800 train loss:  0.08  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=21900 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22100 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22200 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22300 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22400 train loss:  0.04  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22500 train loss:  0.01  train acc: 1.00  val loss:  0.13  valid acc: 0.97
# sin_new i=22600 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22700 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22800 train loss:  0.12  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=22900 train loss:  0.03  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23000 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23100 train loss:  0.26  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23200 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23300 train loss:  0.36  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23400 train loss:  0.19  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23500 train loss:  0.08  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23600 train loss:  0.27  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=23700 train loss:  0.33  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=23800 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=23900 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24000 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24100 train loss:  0.26  train acc: 0.88  val loss:  0.12  valid acc: 0.97
# sin_new i=24200 train loss:  0.05  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24300 train loss:  0.08  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=24400 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=24500 train loss:  0.15  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=24600 train loss:  0.45  train acc: 0.88  val loss:  0.11  valid acc: 0.97
# sin_new i=24700 train loss:  0.01  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=24800 train loss:  0.03  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=24900 train loss:  0.02  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25000 train loss:  0.02  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25100 train loss:  0.11  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25200 train loss:  0.00  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25300 train loss:  0.01  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25400 train loss:  0.06  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25500 train loss:  0.03  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=25600 train loss:  0.00  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25700 train loss:  0.22  train acc: 0.88  val loss:  0.11  valid acc: 0.97
# sin_new i=25800 train loss:  0.01  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=25900 train loss:  0.01  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# sin_new i=26000 train loss:  0.12  train acc: 1.00  val loss:  0.12  valid acc: 0.97
# sin_new i=26100 train loss:  0.00  train acc: 1.00  val loss:  0.11  valid acc: 0.97
# ...
# sin_new i=11400 train loss:  6.84  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=11500 train loss:  6.64  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=11600 train loss:  6.63  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=11700 train loss:  6.86  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=11800 train loss:  6.87  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=11900 train loss:  6.61  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=12000 train loss:  6.88  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=12100 train loss:  6.63  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=12200 train loss:  6.65  train acc: 0.00  val loss:  6.75  valid acc: 0.00
# sin_new i=12300 train loss:  6.77  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=12400 train loss:  6.85  train acc: 0.00  val loss:  6.77  valid acc: 0.00
# sin_new i=12500 train loss:  6.44  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=12600 train loss:  6.67  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=12700 train loss:  6.88  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=12800 train loss:  6.82  train acc: 0.00  val loss:  6.78  valid acc: 0.00
# sin_new i=12900 train loss:  7.05  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=13000 train loss:  6.91  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=13100 train loss:  6.94  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=13200 train loss:  6.84  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=13300 train loss:  6.63  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=13400 train loss:  6.74  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=13500 train loss:  6.54  train acc: 0.00  val loss:  6.78  valid acc: 0.00
# sin_new i=13600 train loss:  6.68  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=13700 train loss:  6.79  train acc: 0.00  val loss:  6.78  valid acc: 0.00
# sin_new i=13800 train loss:  6.65  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=13900 train loss:  6.82  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=14000 train loss:  6.87  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=14100 train loss:  6.55  train acc: 0.12  val loss:  6.80  valid acc: 0.00
# sin_new i=14200 train loss:  6.74  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=14300 train loss:  6.71  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=14400 train loss:  6.67  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=14500 train loss:  6.61  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=14600 train loss:  6.92  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=14700 train loss:  6.62  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=14800 train loss:  6.54  train acc: 0.00  val loss:  6.78  valid acc: 0.00
# sin_new i=14900 train loss:  6.76  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=15000 train loss:  6.92  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=15100 train loss:  6.61  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=15200 train loss:  6.70  train acc: 0.12  val loss:  6.82  valid acc: 0.00
# sin_new i=15300 train loss:  6.90  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=15400 train loss:  6.86  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=15500 train loss:  6.92  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=15600 train loss:  6.71  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=15700 train loss:  6.73  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=15800 train loss:  6.65  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=15900 train loss:  6.87  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=16000 train loss:  6.47  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=16100 train loss:  7.02  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=16200 train loss:  6.80  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=16300 train loss:  6.77  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=16400 train loss:  6.67  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=16500 train loss:  7.05  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=16600 train loss:  6.74  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=16700 train loss:  6.99  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=16800 train loss:  6.93  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=16900 train loss:  6.57  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=17000 train loss:  6.59  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=17100 train loss:  6.49  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=17200 train loss:  6.52  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=17300 train loss:  6.83  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=17400 train loss:  6.57  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=17500 train loss:  6.83  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=17600 train loss:  6.70  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=17700 train loss:  6.86  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=17800 train loss:  7.15  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=17900 train loss:  6.93  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=18000 train loss:  6.49  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=18100 train loss:  6.75  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=18200 train loss:  6.55  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=18300 train loss:  6.80  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=18400 train loss:  6.25  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=18500 train loss:  6.55  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=18600 train loss:  7.03  train acc: 0.00  val loss:  6.80  valid acc: 0.00
# sin_new i=18700 train loss:  6.99  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=18800 train loss:  6.61  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=18900 train loss:  6.37  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=19000 train loss:  6.57  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=19100 train loss:  6.82  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=19200 train loss:  6.73  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=19300 train loss:  6.62  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=19400 train loss:  6.57  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=19500 train loss:  6.71  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=19600 train loss:  6.50  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=19700 train loss:  6.73  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=19800 train loss:  7.11  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=19900 train loss:  6.65  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=20000 train loss:  6.94  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=20100 train loss:  6.61  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=20200 train loss:  6.50  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=20300 train loss:  6.87  train acc: 0.00  val loss:  6.79  valid acc: 0.00
# sin_new i=20400 train loss:  6.62  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=20500 train loss:  6.58  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=20600 train loss:  6.71  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=20700 train loss:  6.68  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=20800 train loss:  6.80  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=20900 train loss:  6.91  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=21000 train loss:  7.04  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=21100 train loss:  6.39  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=21200 train loss:  6.55  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=21300 train loss:  7.07  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=21400 train loss:  6.59  train acc: 0.00  val loss:  6.81  valid acc: 0.00
# sin_new i=21500 train loss:  7.09  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=21600 train loss:  6.67  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=21700 train loss:  6.59  train acc: 0.12  val loss:  6.83  valid acc: 0.00
# sin_new i=21800 train loss:  6.72  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=21900 train loss:  6.87  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=22000 train loss:  6.54  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=22100 train loss:  6.60  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=22200 train loss:  6.76  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=22300 train loss:  6.62  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=22400 train loss:  6.91  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=22500 train loss:  6.56  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=22600 train loss:  6.48  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=22700 train loss:  6.96  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=22800 train loss:  6.41  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=22900 train loss:  6.91  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=23000 train loss:  7.26  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=23100 train loss:  6.42  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=23200 train loss:  6.59  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=23300 train loss:  6.80  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=23400 train loss:  6.70  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=23500 train loss:  6.53  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=23600 train loss:  6.86  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=23700 train loss:  7.02  train acc: 0.00  val loss:  6.83  valid acc: 0.00
# sin_new i=23800 train loss:  6.74  train acc: 0.00  val loss:  6.82  valid acc: 0.00
# sin_new i=23900 train loss:  6.78  train acc: 0.12  val loss:  6.86  valid acc: 0.00
# sin_new i=24000 train loss:  6.83  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=24100 train loss:  6.64  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=24200 train loss:  7.18  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=24300 train loss:  6.69  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=24400 train loss:  6.57  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=24500 train loss:  7.13  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=24600 train loss:  6.80  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=24700 train loss:  6.77  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=24800 train loss:  6.70  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=24900 train loss:  6.95  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=25000 train loss:  6.78  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=25100 train loss:  6.63  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=25200 train loss:  6.68  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=25300 train loss:  6.80  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=25400 train loss:  6.73  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=25500 train loss:  6.58  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=25600 train loss:  6.61  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=25700 train loss:  6.49  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=25800 train loss:  6.41  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=25900 train loss:  6.72  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=26000 train loss:  6.67  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=26100 train loss:  6.53  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=26200 train loss:  6.72  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=26300 train loss:  6.64  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=26400 train loss:  6.71  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=26500 train loss:  6.62  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=26600 train loss:  6.83  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=26700 train loss:  6.75  train acc: 0.00  val loss:  6.84  valid acc: 0.00
# sin_new i=26800 train loss:  6.63  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=26900 train loss:  6.57  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=27000 train loss:  6.71  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=27100 train loss:  6.72  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=27200 train loss:  6.64  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=27300 train loss:  6.59  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=27400 train loss:  6.79  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=27500 train loss:  6.51  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=27600 train loss:  6.40  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=27700 train loss:  6.46  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=27800 train loss:  6.63  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=27900 train loss:  6.52  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=28000 train loss:  7.13  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=28100 train loss:  6.81  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=28200 train loss:  6.75  train acc: 0.00  val loss:  6.86  valid acc: 0.00
# sin_new i=28300 train loss:  6.58  train acc: 0.00  val loss:  6.85  valid acc: 0.00
# sin_new i=28400 train loss:  6.67  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=28500 train loss:  6.47  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=28600 train loss:  7.03  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=28700 train loss:  6.74  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=28800 train loss:  6.76  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=28900 train loss:  6.72  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=29000 train loss:  6.79  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=29100 train loss:  6.80  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=29200 train loss:  6.58  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=29300 train loss:  6.71  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=29400 train loss:  6.45  train acc: 0.00  val loss:  6.91  valid acc: 0.00
# sin_new i=29500 train loss:  6.62  train acc: 0.00  val loss:  6.88  valid acc: 0.00
# sin_new i=29600 train loss:  6.66  train acc: 0.00  val loss:  6.89  valid acc: 0.00
# sin_new i=29700 train loss:  6.83  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=29800 train loss:  6.75  train acc: 0.00  val loss:  6.87  valid acc: 0.00
# sin_new i=29900 train loss:  6.65  train acc: 0.00  val loss:  6.90  valid acc: 0.00
# sin_new i=30000 train loss:  6.38  train acc: 0.12  val loss:  6.89  valid acc: 0.00
# -> sin_new layer idx: 0  , best valid accuracy: 0.00, test accuracy: 0.00

# %%
print("adfs")
# Out:
# adfs

# %%
# save the results for visualizations & further analyses
import pandas as pd

df = pd.DataFrame({"probe_l%s" % k: v.cpu() for k, v in test_extracted.items()})
df["model_predictions"] = test_preds_t.cpu()
df["inputs"] = [make_str_input_add(op) for op in test_inputs]
df["labels"] = test_labels_ref.cpu()

# %% [markdown]
# ### Collecting the results of per-layer ablations

# %%
# import gc
# gc.collect()
#
# accs = []
#
# device = "cuda:3"
#
# for l_i in range(len(test_extracted) - 1):
#     model = transformers.AutoModel.from_pretrained(model_ckpt).eval().to(device)
#     del model.layers[l_i]  # intervention -- dropping a single layer
#
#     test_hidden_states, test_preds = get_hidden_states_and_preds(
#         model,
#         [make_str_input_add(val) for val in test_inputs],
#         batch_size
#     )
#     test_preds_t = torch.tensor([sanitize_pred(pred) for pred in test_preds])
#
#     # absolute model accuracy on test set
#     df["model_predictions_without_l%s" % l_i] = test_preds_t.detach().cpu().tolist()
#
#     acc = (sum(test_preds_t.to(device) == test_labels_ref.to(device)) / len(test_inputs)).item()
#
#     accs.append(acc)
#     model = None
#     gc.collect()
#
#     print("Acc without layer %s: %s" % (l_i, acc))

# %%
print("afsd")
# Out:
# afsd

# %%
# this output can be visualized using notebooks/viz/timothee_error_tracing.ipynb
df.to_csv("/home/USER/tmp/pycharm_project_437/notebooks/logs/model_vs_probes_preds_llama3b_add_040126_onlynewprobe.csv", index=False)

# %%
# basic statistics of result recovery

is_result_computed_per_l = torch.vstack([test_extracted[l_key] == test_labels_ref for l_key in test_extracted])
is_result_computed_internally = torch.any(is_result_computed_per_l, dim=0).cpu()
returned_val_is_computed = torch.vstack([test_extracted[l_key].cpu() == test_preds_t for l_key in test_extracted])
is_result_returned = (test_preds_t == test_labels_ref.cpu())
print(
      "Ever computed correctly internally and NOT correctly returned (out of incorrect): %s\n"
      "NOT ever computed correctly internally and correctly returned: (out of correct) %s\n"
      "Ever computed correctly internally and correctly returned (out of correct): %s\n"
      "NOT ever computed correctly internally and NOT correctly returned (out of incorrect): %s\n"
      "Ever computed as returned: %s"
      % (
         torch.sum(is_result_computed_internally & ~is_result_returned).item() / (~is_result_returned).sum(),
         torch.sum(~is_result_computed_internally & is_result_returned).item() / is_result_returned.sum(),
         torch.sum(is_result_computed_internally & is_result_returned).item() / is_result_returned.sum(),
         torch.sum(~is_result_computed_internally & ~is_result_returned).item() / (~is_result_returned).sum(),
         returned_val_is_computed.any(dim=0).sum() / len(returned_val_is_computed[0]))
        )

# %%
# ratios of cases with multiplication involving "1" or "2"

# in the case of Llama 1B, 15 out of 25 correct contains multiplication involving "1" or "2" --> effectively solvable by addition
# only 30 out of 140 in the case of Llama 3B
(len(test_labels_ref[~is_result_computed_internally & is_result_returned]),
torch.isin(test_inputs_t[~is_result_computed_internally & is_result_returned], torch.tensor([1, 2])).any(dim=1).sum())

# %%
# baseline probes fitting (lin+log)

def solve_linear_layer(x: Tensor, y: Tensor) -> torch.nn.Linear:
    if y.ndim == 1:
        y = y.unsqueeze(-1)
    if not y.is_floating_point():
        y = y.float()
   
    lin = torch.nn.Linear(x.shape[-1], y.shape[-1], device=x.device)
    x_aug = torch.cat([x, torch.ones(len(x), 1, device=x.device)], dim=1)
    coeffs = torch.linalg.lstsq(x_aug, y).solution
    w, b = coeffs[:-1], coeffs[-1]
    with torch.no_grad():
        lin.weight[:] = w.T
        lin.bias[:] = b
    return lin

# %%
for layer_idx in reversed(test_hidden_states.keys()):
    lin_probe = solve_linear_layer(
        train_hidden_states[layer_idx].float().to(device),
        train_labels.to(device),
    )
    log_probe = solve_linear_layer(
        train_hidden_states[layer_idx].float().to(device),
        train_labels.log1p().to(device),
    )
    lin_test_pred = lin_probe(test_hidden_states[layer_idx].float().to(device)).flatten().round().int()
    lin_test_accuracy = (lin_test_pred == test_labels.to(lin_test_pred.device)).float().mean().item()
    
    log_test_pred = log_probe(test_hidden_states[layer_idx].float().to(device)).flatten().exp().add(1).round().int()
    log_test_accuracy = (log_test_pred == test_labels.to(log_test_pred.device)).float().mean().item()
    
    test_accuracies["lin"][layer_idx] = lin_test_accuracy
    test_accuracies["log"][layer_idx] = log_test_accuracy

    print(f"layer idx: {layer_idx:<3}, linear probe acc: {lin_test_accuracy:.2f}, log probe acc: {log_test_accuracy:.2f}")

# %%
for name, accs in test_accuracies.items():
    print(f"{name} accs: | " + " | ".join([f"{x:.0%}" for layer, x in sorted(accs.items())]) + " |")
